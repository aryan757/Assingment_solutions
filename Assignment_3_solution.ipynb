# %% [markdown]
# # 1. Why are functions advantageous to have in your programs?

# %%
Because function makes the program 

1 . structured 
2 . it can be called and used anytime as per needed 
3 . Reducing duplication of code.
4 . Decomposing complex problems into simpler pieces.
5 . Improving clarity of the code.
6 . Reuse of code.
7 . Information hiding.

# %% [markdown]
# # 2. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# When it is called , then only fuction or program counter goes to the function stack and try to excute the called function and after completion it will return to the parent function like main() where it was called initially !

# %% [markdown]
# # 3. What statement creates a function?

# %%
def function_name(a,b):
    print("the first parameter",a ,"the second parameter" , b)

# %%
function_name(1,2)
# Out:
# the first parameter 1 the second parameter 2

# %% [markdown]
# # 4. What is the difference between a function and a function call?

# %%
A function is a block of code that does a particular operation and returns a result. It usually accepts inputs as parameters and returns a result. The parameters are not mandatory. A function call is the code used to pass control to a function.

# %% [markdown]
# # 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# A function is a block of code that does a particular operation and returns a result. It usually accepts inputs as parameters and returns a result. The parameters are not mandatory. A function call is the code used to pass control to a function
#
# ![2022-06-28%20%282%29.png](attachment:2022-06-28%20%282%29.png)

# %% [markdown]
# # 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# When the execution of the function terminates (returns), the local variables are destroyed. Codelens helps you visualize this because the local variables disappear after the function returns.

# %% [markdown]
# # 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# In general, a function takes arguments (if any), performs some operations, and returns a value (or object). The value that a function returns to the caller is generally known as the function's return value. All Python functions have a return value, either explicit or implicit.
#
#
# A return statement is used to end the execution of the function call and “returns” the result (value of the expression following the return keyword) to the caller. The statements after the return statements are not executed. If the return statement is without any expression, then the special value None is returned.

# %% [markdown]
# # 8. If a function does not have a return statement, what is the return value of a call to that function?

# %%
def funct(a,b):
    print("hello",a,b)

# %%
a = funct(1,3)
# Out:
# hello 1 3

# %%
a  ## Return NONE

# %%
def funct(a,b):
    return a,b

# %%
a = funct(1,3)

# %%
a  ## With using Return , it will return as it specified using return keyword !
# Out:
# (1, 3)

# %% [markdown]
# # 9. How do you make a function variable refer to the global variable?

# %%
x = 12
 
def funct():
    # using a global keyword
    global x
 
    
    x = x + 2
    print("Value of x inside a function :", x)

# %%
funct()
# Out:
# Value of x inside a function : 14

# %% [markdown]
# Here , ny using the global keyword ! we are accesing the globally declared varaible inside the function , funct?()

# %% [markdown]
# # 10. What is the data type of None?

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# # 11. What does the sentence import areallyourpetsnamederic do?

# %%
import areallyourpetsnamederic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 import areallyourpetsnamederic
#
# ModuleNotFoundError: No module named 'areallyourpetsnamederic'

# %% [markdown]
# Since , no module exist by such name it will import nothing ! , if we explicitly defined any such file or module , then importing this will no such an issue for the user

# %% [markdown]
# # 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %%
import spam 
spam.bacon()

# %% [markdown]
# # 13. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# The moment we get an error in a code , can be prevented by putting the suspicious code inside the try block ,
# and later using except keyword , we can trace out an print the error details .

# %%
def test(a):
    try :
        4/a
        print("succesful")
    except Exception as e :
        print("error is" ,e)

# %%
test(5)
# Out:
# succesful

# %%
test(0)
# Out:
# error is division by zero
